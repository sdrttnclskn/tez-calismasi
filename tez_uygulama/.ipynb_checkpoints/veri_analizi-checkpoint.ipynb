# %% [markdown]
# # Veri hakkında bilgi

# %%
#### Veri seti okuma #####
import pandas as pd
veriseti = pd.read_excel("/Users/sdrttnclskn/Desktop/tez/tez-calismasi/tez_uygulama/veri_seti.xlsx")
df = veriseti.copy()
df.head()
# Out:
#        TARIH              FONTIP             FONTUR  FON  Unnamed: 4  \
# 0 2019-01-02  BORSA YATIRIM FONU         Altın Fonu  FGA         NaN
# 1 2019-01-02  BORSA YATIRIM FONU         Gümüş Fonu  FGS         NaN
# 2 2019-01-02  BORSA YATIRIM FONU  Hisse Senedi Fonu  DJA         NaN
# 3 2019-01-02      EMEKLİLİK FONU         Altın Fonu  AEA         NaN
# 4 2019-01-02      EMEKLİLİK FONU         Altın Fonu  AEL         NaN
#
#    FONTOPLAMDEGER  TEDAVPAYSAYISI  KISISAYISI   FONFIYAT    FAIZ  ...  TR  \
# 0    8.722176e+07    4.350000e+06           0  20.050979  0.2302  ... NaN
# 1    1.238294e+07    7.000000e+05           0  17.689916  0.2302  ... NaN
# 2    1.491130e+07    4.800000e+05           0  31.065216  0.2302  ... NaN
# 3    1.465104e+09    6.335717e+10      325392   0.023125  0.2302  ... NaN
# 4    1.784293e+09    7.415738e+10      325460   0.024061  0.2302  ... NaN
#
#    TPP   T  VM  VDM  YBA  YHS  YMK   D   R
# 0  NaN NaN NaN  NaN  NaN  NaN  NaN NaN NaN
# ...

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187438 entries, 0 to 187437
# Data columns (total 38 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   TARIH           187438 non-null  datetime64[ns]
#  1   FONTIP          187438 non-null  object
#  2   FONTUR          187438 non-null  object
#  3   FON             187438 non-null  object
#  4   Unnamed: 4      0 non-null       float64
#  5   FONTOPLAMDEGER  187438 non-null  float64
#  6   TEDAVPAYSAYISI  187438 non-null  float64
#  7   KISISAYISI      187438 non-null  int64
#  8   FONFIYAT        187438 non-null  float64
#  9   FAIZ            187438 non-null  float64
#  10  DOLARFIYAT      187438 non-null  float64
#  11  ALTINFIYAT      187438 non-null  float64
#  12  BB              187438 non-null  float64
#  13  DT              185256 non-null  float64
#  14  DB              173992 non-null  float64
#  15  DÖT             148075 non-null  float64
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# TARIH                  0
# FONTIP                 0
# FONTUR                 0
# FON                    0
# Unnamed: 4        187438
# FONTOPLAMDEGER         0
# TEDAVPAYSAYISI         0
# KISISAYISI             0
# FONFIYAT               0
# FAIZ                   0
# DOLARFIYAT             0
# ALTINFIYAT             0
# BB                     0
# DT                  2182
# DB                 13446
# DÖT                39363
# EUT                73647
# FB                103116
# FKB               132060
# GAS               152635
# HB                166216
# HS                175575
# KBA               181116
# KKS               184745
# KH                186222
# KM                186890
# OSKS              187227
# OST               187427
# TR                187438
# TPP               187438
# T                 187438
# VM                187438
# VDM               187438
# YBA               187438
# YHS               187438
# YMK               187438
# D                 187438
# ...

# %%
df.tail()
# Out:
#             TARIH        FONTIP       FONTUR  FON  Unnamed: 4  FONTOPLAMDEGER  \
# 187433 2019-12-31  YATIRIM FONU  Serbest Fon  UPD         NaN    5.113163e+07
# 187434 2019-12-31  YATIRIM FONU  Serbest Fon  UPS         NaN    1.547605e+07
# 187435 2019-12-31  YATIRIM FONU  Serbest Fon  UPU         NaN    1.054165e+06
# 187436 2019-12-31  YATIRIM FONU  Serbest Fon  USY         NaN    8.851681e+06
# 187437 2019-12-31  YATIRIM FONU  Serbest Fon  ZPA         NaN    5.204444e+08
#
#         TEDAVPAYSAYISI  KISISAYISI  FONFIYAT    FAIZ  ...  TR  TPP   T  VM  \
# 187433      24459866.0         105  2.090430  0.1138  ... NaN  NaN NaN NaN
# 187434       2401832.0           1  6.443434  0.1138  ... NaN  NaN NaN NaN
# 187435        573729.0           2  1.837393  0.1138  ... NaN  NaN NaN NaN
# 187436     441725675.0           1  0.020039  0.1138  ... NaN  NaN NaN NaN
# 187437     351412827.0           1  1.481006  0.1138  ... NaN  NaN NaN NaN
#
#         VDM  YBA  YHS  YMK   D   R
# ...

# %%
df.describe().T
# Out:
#                    count          mean           std            min  \
# Unnamed: 4           0.0           NaN           NaN            NaN
# FONTOPLAMDEGER  187438.0  2.394037e+08  5.509213e+08       0.000000
# TEDAVPAYSAYISI  187438.0  6.301665e+09  1.704090e+10       0.000000
# KISISAYISI      187438.0  4.325684e+04  1.049055e+05       0.000000
# FONFIYAT        187438.0  3.982973e+00  2.395512e+01       0.000000
# FAIZ            187438.0  2.034597e-01  4.610195e-02       0.105100
# DOLARFIYAT      187438.0  5.683442e+00  2.214480e-01       5.203800
# ALTINFIYAT      187438.0  2.527867e+05  2.080213e+04  216132.634958
# BB              187438.0  4.071823e+01  3.596555e+01     -90.330000
# DT              185256.0  2.322606e+01  2.809720e+01    -119.570000
# DB              173992.0  1.611707e+01  2.267205e+01     -16.150000
# DÖT             148075.0  1.074313e+01  1.589276e+01     -23.390000
# EUT             113791.0  9.675534e+00  1.532893e+01     -83.930000
# ...

# %%
## her bir kolon için unique veri sayısı
uniq_data={}
for col in df:
    uniq_data[col] = df[col].unique()
uniq_data

# %%
df['FON'].nunique()
# Out:
# 892

# %%
from IPython.display import HTML, display


display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in df)
       )
))
